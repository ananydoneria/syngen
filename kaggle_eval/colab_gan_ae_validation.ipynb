# %% [markdown]
# # GAN+AE Kaggle Validation (Colab)
#
# This notebook runs the project pipeline on Colab T4.
#
# Steps:
# 1. Set runtime to **GPU (T4)**.
# 2. Mount Drive (optional) or clone/upload project.
# 3. Run preflight check (no training).
# 4. Start full training+validation.

# %%
# !nvidia-smi

# %%
# If needed, clone your repo here. Example:
# !git clone <YOUR_REPO_URL>
# %cd <YOUR_REPO_FOLDER>

# Or if project files are already present in current directory, keep as-is.
# %pwd

# %%
# !python -m pip install -q kagglehub pandas scipy scikit-learn

# %%
# Preflight only (verifies GPU + Kaggle download + write access).
# !python kaggle_eval/run_kaggle_validation.py --preflight-only --expect-gpu

# %%
# Full run (downloads, trains, generates, compares, writes report).
# !python kaggle_eval/run_kaggle_validation.py

# %%
# !ls -lah kaggle_eval/output
